# %% [markdown]
# # Python Codes

# %% [markdown]
# ## 1.Python Foundations

# %% [markdown]
# ### Simple Arithmetic

# %%
a=5
b=10
c=a+b
print(a+b)
# Out:
# 15

# %% [markdown]
# ### Simple Arithmetic - Get input from User (+,-,*,%)

# %%
a=(float)(input("Enter a number :"))
b=(float)(input("Enter a number :"))
add=a+b
sub=a-b
mult=a*b
div=a/b
mod=a%b
print(add)
print("addition:{0}, subtraction:{1}, multiplication:{2}, division:{3}, and mod:{4}".format(add,sub,mult,div,mod)) #print using format
print("Sum: %d, Diff: %d, Mult: %d, Div:%15.6f, Mod:%d"%(add,sub,mult,div,mod)) #Print using PADDING & PRECISION

print('{0:<4} | {1:^4} | {2:^4} | {3:>4}'.format('Sum','Diff','Mult','Div'))
print('{0:<4} | {1:^4} | {2:^4} | {3:>4}'.format(add,sub,mult,div))
# Out:
# Enter a number : 5
# Enter a number : 4
# 9.0
# addition:9.0, subtraction:1.0, multiplication:20.0, division:1.25, and mod:1.0
# Sum: 9, Diff: 1, Mult: 20, Div:       1.250000, Mod:1
# Sum  | Diff | Mult |  Div
# 9.0  | 1.0  | 20.0 | 1.25
